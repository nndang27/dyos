# %%
x = 10
y = 20
name = 'AI'
print(f'x+y={x+y}')
# Out:
# x+y=30

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(1000, 4), columns=list('ABCD'))
df.head()
# Out:
#           A         B         C         D
# 0 -0.224260  0.825667 -0.313551  0.046400
# 1 -0.263159 -0.939944  0.495943  1.131533
# 2  1.194670  0.876913 -0.075526 -1.267525
# 3 -0.248595 -1.797789  0.339186  0.291488
# 4 -1.182991 -0.934122 -1.459674 -0.197146

# %%
# %pip install matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
plt.plot(np.random.randn(50))
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
1/0

# %%
import time
while True:
    time.sleep(0.1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 import time
#       2 while True:
# ----> 3     time.sleep(0.1)
#
# KeyboardInterrupt:
